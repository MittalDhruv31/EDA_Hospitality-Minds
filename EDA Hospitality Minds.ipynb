# %%
#dataset path="C:\Users\Dhruv\Downloads\Hospitality minds dataset.csv"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"E:\downloads\Hospitality minds dataset.csv")
df
# Out:
#       Type of Hotel  Year     Month Reservation Date  Arrival week  \
# 0             Motel  2015      July       03-08-2015            31
# 1             Villa  2016    August       30-08-2016            35
# 2             Villa  2017     April       23-04-2017            16
# 3             Motel  2016      June       29-06-2016            27
# 4             Motel  2016    August       22-08-2016            34
# ...             ...   ...       ...              ...           ...
# 89995         Motel  2017     April       07-01-2017            15
# 89996         Villa  2016     April       01-03-2016            17
# 89997         Motel  2017      July       10-07-2017            27
# 89998         Motel  2016  December       26-12-2016            52
# 89999         Motel  2017   January       21-10-2016             4
#
#        Arrival Date  Weekend Stays  Weekday Stays                Meal  \
# 0                28              2              3     Bed & Breakfast
# ...

# %%
pd.set_option('display.max_columns',50)

# %%
df
# Out:
#       Type of Hotel  Year     Month Reservation Date  Arrival week  \
# 0             Motel  2015      July       03-08-2015            31
# 1             Villa  2016    August       30-08-2016            35
# 2             Villa  2017     April       23-04-2017            16
# 3             Motel  2016      June       29-06-2016            27
# 4             Motel  2016    August       22-08-2016            34
# ...             ...   ...       ...              ...           ...
# 89995         Motel  2017     April       07-01-2017            15
# 89996         Villa  2016     April       01-03-2016            17
# 89997         Motel  2017      July       10-07-2017            27
# 89998         Motel  2016  December       26-12-2016            52
# 89999         Motel  2017   January       21-10-2016             4
#
#        Arrival Date  Weekend Stays  Weekday Stays                Meal  \
# 0                28              2              3     Bed & Breakfast
# ...

# %%
cols=df.columns
cols
for i in cols:
    print(df[i].value_counts())
# Out:
# Motel    60192
# Villa    29808
# Name: Type of Hotel, dtype: int64
# 2016    42208
# 2017    31488
# 2015    16304
# Name: Year, dtype: int64
# August       10796
# July          9334
# May           9252
# June          8600
# April         8276
# October       8269
# September     7634
# March         7525
# February      5975
# December      5025
# November      4708
# January       4606
# Name: Month, dtype: int64
# 21-10-2015    1387
# 01-01-2015     589
# 06-07-2015     508
# 02-07-2015     430
# 25-11-2016     407
#               ...
# 17-12-2014       1
# 25-03-2015       1
# 22-04-2015       1
# 17-02-2015       1
# 05-02-2015       1
# Name: Reservation Date, Length: 976, dtype: int64
# 30    3385
# 10    3210
# 49    3066
# 39    2659
# 27    2596
# 31    2560
# 33    2370
# 32    2347
# 18    2259
# 34    2242
# 17    2227
# 26    2215
# 19    2212
# 25    2210
# 35    2175
# 42    2144
# 21    2098
# 15    2065
# 41    1980
# 20    1972
# 38    1910
# 22    1879
# ...

# %%
df.isna().sum()
# Out:
# Type of Hotel            0
# Year                     0
# Month                    0
# Reservation Date         0
# Arrival week             0
# Arrival Date             0
# Weekend Stays            0
# Weekday Stays            0
# Meal                     0
# Booking Payment          0
# Adults                   0
# Children                 2
# Kids                     0
# Country                371
# Booking Type             0
# Repeated Guest           0
# Prev Cancel              0
# History                  0
# Reserved Room            0
# Assigned Room            0
# Booking Changes          0
# Waiting List             0
# Customer                 0
# Per Day Charges          0
# Parking at premises      0
# Physical Challenged      0
# Reservation Status       0
# Cancellation             0
# Booking Done             0
# dtype: int64

# %%
df[df['Children'].isna()]
# Out:
#       Type of Hotel  Year   Month Reservation Date  Arrival week  \
# 57938         Motel  2015  August       07-08-2015            32
# 63282         Motel  2015  August       08-08-2015            32
#
#        Arrival Date  Weekend Stays  Weekday Stays             Meal  \
# 57938             3              0              1  Bed & Breakfast
# 63282             5              0              5  Bed & Breakfast
#
#       Booking Payment  Adults  Children  Kids Country Booking Type  \
# 57938      No Deposit       2       NaN     0     PRT    Online TA
# 63282      No Deposit       2       NaN     0     PRT      Website
#
#        Repeated Guest  Prev Cancel  History Reserved Room Assigned Room  \
# 57938               0            0        0             B             B
# 63282               0            0        0             B             B
#
#        Booking Changes  Waiting List         Customer  Per Day Charges  \
# ...

# %%
df['Children'].fillna(0,inplace=True)

# %%
df[df['Country'].isna()]
# Out:
#       Type of Hotel  Year     Month Reservation Date  Arrival week  \
# 124           Villa  2017     April       01-05-2017            17
# 212           Villa  2016     March       14-03-2016            11
# 333           Villa  2015      July       12-07-2015            28
# 531           Villa  2016     April       23-04-2016            17
# 662           Villa  2016     April       03-05-2016            18
# ...             ...   ...       ...              ...           ...
# 88626         Villa  2016  December       14-12-2016            51
# 88983         Villa  2016       May       19-05-2016            21
# 89602         Villa  2016       May       03-05-2016            19
# 89851         Villa  2016   October       17-10-2016            43
# 89914         Villa  2016   January       18-01-2016             4
#
#        Arrival Date  Weekend Stays  Weekday Stays             Meal  \
# 124              28              2              2  Bed & Breakfast
# ...

# %%
df.fillna('Undisclosed',inplace=True)

# %%
df.isna().sum()
# Out:
# Type of Hotel          0
# Year                   0
# Month                  0
# Reservation Date       0
# Arrival week           0
# Arrival Date           0
# Weekend Stays          0
# Weekday Stays          0
# Meal                   0
# Booking Payment        0
# Adults                 0
# Children               0
# Kids                   0
# Country                0
# Booking Type           0
# Repeated Guest         0
# Prev Cancel            0
# History                0
# Reserved Room          0
# Assigned Room          0
# Booking Changes        0
# Waiting List           0
# Customer               0
# Per Day Charges        0
# Parking at premises    0
# Physical Challenged    0
# Reservation Status     0
# Cancellation           0
# Booking Done           0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#       Type of Hotel  Year      Month Reservation Date  Arrival week  \
# 10106         Motel  2016       June       21-10-2015            25
# 10619         Motel  2017      March       21-10-2015             9
# 13404         Motel  2015   December       23-07-2015            49
# 14003         Motel  2015     August       06-07-2015            33
# 14073         Motel  2015     August       01-01-2015            31
# ...             ...   ...        ...              ...           ...
# 87924         Motel  2016   December       21-10-2015            53
# 88661         Motel  2015     August       02-07-2015            32
# 89570         Motel  2017      March       21-10-2015            13
# 89651         Motel  2015    October       02-07-2015            41
# 89700         Motel  2015  September       06-07-2015            38
#
#        Arrival Date  Weekend Stays  Weekday Stays                Meal  \
# 10106            16              0              2     Bed & Breakfast
# ...

# %%
df['Total_Members']=df['Adults']+df['Children']+df['Kids']+df['Physical Challenged']
df['Total_Members']=df['Total_Members'].astype('int')

# %%
len(df[df['Total_Members']==0].index)
# Out:
# 82

# %%
#entries with no members ar wrong entries
df.drop(index=df[df['Total_Members']==0].index,inplace=True)

# %%
nc_df=df[df['Cancellation']==0]
c_df=df[df['Cancellation']==1]

# %%
nc_df['Total_Stay_Days']=nc_df['Weekday Stays']+nc_df['Weekend Stays']
# Out:
# C:\Users\Dhruv\AppData\Local\Temp\ipykernel_14592\3433863907.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nc_df['Total_Stay_Days']=nc_df['Weekday Stays']+nc_df['Weekend Stays']

# %%
nc_df['Revenue']=nc_df['Total_Stay_Days']*nc_df['Per Day Charges']
# Out:
# C:\Users\Dhruv\AppData\Local\Temp\ipykernel_14592\3381298534.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nc_df['Revenue']=nc_df['Total_Stay_Days']*nc_df['Per Day Charges']

# %%
nc_df
# Out:
#       Type of Hotel  Year     Month Reservation Date  Arrival week  \
# 0             Motel  2015      July       03-08-2015            31
# 1             Villa  2016    August       30-08-2016            35
# 2             Villa  2017     April       23-04-2017            16
# 3             Motel  2016      June       29-06-2016            27
# 4             Motel  2016    August       22-08-2016            34
# ...             ...   ...       ...              ...           ...
# 89992         Villa  2016     April       23-04-2016            17
# 89993         Villa  2015    August       21-08-2015            33
# 89994         Villa  2016  December       18-12-2016            51
# 89997         Motel  2017      July       10-07-2017            27
# 89998         Motel  2016  December       26-12-2016            52
#
#        Arrival Date  Weekend Stays  Weekday Stays                Meal  \
# 0                28              2              3     Bed & Breakfast
# ...

# %%
corr=df.corr()
plt.figure(figsize=(14,7))
sns.heatmap(corr,annot=True)
plt.title('Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
t=df['Type of Hotel'].value_counts()
x=t.values
y=t.keys()
plt.figure(figsize=(14,7))
plt.pie(x,labels=y)
plt.title('Motel and Villa Customer preference Split')
plt.show()

# %%
sns.countplot(x=df['Year'])
plt.title('Total Expected Customer Arrivals')
plt.show()

# %%
sns.countplot(x=nc_df['Year'])
plt.title('Total Actual Customer Arrivals')
plt.show()

# %%
df.sort_values(by='Reservation Date')
# Out:
#       Type of Hotel  Year      Month Reservation Date  Arrival week  \
# 57789         Motel  2015    October       01-01-2015            41
# 2217          Motel  2015     August       01-01-2015            32
# 31324         Motel  2015    October       01-01-2015            42
# 58094         Motel  2015    October       01-01-2015            43
# 36730         Motel  2015  September       01-01-2015            39
# ...             ...   ...        ...              ...           ...
# 33073         Villa  2016   December       31-12-2016            53
# 85167         Villa  2017        May       31-12-2016            18
# 42305         Villa  2016   December       31-12-2016            53
# 22006         Motel  2016   December       31-12-2016            52
# 36613         Motel  2017    January       31-12-2016             1
#
#        Arrival Date  Weekend Stays  Weekday Stays             Meal  \
# 57789             6              1              2  Bed & Breakfast
# ...

# %%
t=df.groupby('Month')['Year'].count()
x=t.keys()
y=t.values

# %%
plt.figure(figsize=(14,7))
plt.plot(x,y)
plt.title('Monthly Customer Count Analysis')
plt.show()

# %%
t=df.groupby('Arrival Date')['Year'].count()
x=t.keys()
y=t.values

# %%
plt.figure(figsize=(14,7))
plt.plot(x,y)
plt.xticks(x)
plt.title('Busiest Arrival Days')
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.countplot(x=nc_df['Meal'])
plt.title('Customer Meal Preference')
plt.show()

# %%
pd.pivot_table(values='Repeated Guest',index='Meal',columns='Total_Members',data=df,aggfunc='count')
# Out:
# Total_Members                  1        2        3       4       5      6   \
# Meal
# All Inclusive               129.0    454.0    110.0    39.0    22.0    5.0
# Bed & Breakfast            9899.0  28496.0  17156.0  9095.0  3355.0  972.0
# Breakfast & Dinner         1156.0   4960.0   2660.0  1372.0   583.0  176.0
# Breakfast, Lunch & Dinner    43.0    288.0     97.0    69.0    18.0    1.0
# Room Only                   559.0   3350.0   3224.0  1072.0   226.0   43.0
#
# Total_Members                 7     8    9    10   26
# Meal
# All Inclusive                4.0   NaN  NaN  NaN  NaN
# Bed & Breakfast            171.0  23.0  3.0  1.0  5.0
# Breakfast & Dinner          59.0  13.0  NaN  NaN  1.0
# Breakfast, Lunch & Dinner    2.0   NaN  NaN  NaN  NaN
# Room Only                    6.0   1.0  NaN  NaN  NaN

# %%
plt.figure(figsize=(14,7))
sns.barplot(x=nc_df['Month'],y=nc_df['Revenue'])
plt.title('Total Revenue by Month (in US$)')
plt.show()

# %%
z=df.groupby('Month')['Cancellation'].sum().sort_values(ascending=False)

# %%
x=z.keys()
y=z.values

# %%
plt.figure(figsize=(14,7))
sns.barplot(x,y)
plt.xlabel('Months')
plt.ylabel('Cancellation Count')
plt.title('Cancellations by Month')
plt.show()
# Out:
# C:\Users\Dhruv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(14,7))
sns.countplot(x=nc_df['Arrival week'])
plt.title('Busiest weeks by Customer Arrivals')
plt.show()

# %%
sns.boxplot(y='Per Day Charges',data=df,x='Weekend Stays')
# Out:
# <AxesSubplot:xlabel='Weekend Stays', ylabel='Per Day Charges'>

# %%
sns.boxplot(y='Per Day Charges',data=df,x='Weekday Stays')
# Out:
# <AxesSubplot:xlabel='Weekday Stays', ylabel='Per Day Charges'>

# %%
nk_df=df[(df['Children']==0)&(df['Kids']==0)]
k_df=df[(df['Children']!=0) | (df['Kids']!=0)]
k_df
# Out:
#       Type of Hotel  Year     Month Reservation Date  Arrival week  \
# 47            Villa  2016       May       12-04-2016            22
# 50            Motel  2016      July       16-07-2016            29
# 60            Motel  2017       May       12-05-2017            19
# 79            Villa  2016      July       20-07-2016            28
# 84            Motel  2016    August       28-08-2016            35
# ...             ...   ...       ...              ...           ...
# 89965         Motel  2016     April       15-04-2016            16
# 89983         Motel  2017      July       11-07-2017            27
# 89986         Motel  2017     April       03-02-2017            16
# 89991         Villa  2016    August       27-08-2016            36
# 89998         Motel  2016  December       26-12-2016            52
#
#        Arrival Date  Weekend Stays  Weekday Stays                Meal  \
# 47               27              2              6     Bed & Breakfast
# ...

# %%
z=k_df.groupby('Meal')['Meal'].count().sort_values(ascending=False)
x=z.keys()
y=z.values
z
# Out:
# Meal
# Bed & Breakfast              5717
# Breakfast & Dinner           1185
# Room Only                     154
# Breakfast, Lunch & Dinner      72
# All Inclusive                  56
# Name: Meal, dtype: int64

# %%
plt.figure(figsize=(14,7))
sns.barplot(x,y,palette="dark:#5A9_r")
plt.xlabel('Meal Preference')
plt.ylabel('Customer Count')
plt.title('Meal Preference of Customers with Chilren or Kids')
plt.show()
# Out:
# C:\Users\Dhruv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
z=nk_df.groupby('Meal')['Meal'].count().sort_values(ascending=False)
x=z.keys()
y=z.values
z
# Out:
# Meal
# Bed & Breakfast              63459
# Breakfast & Dinner            9795
# Room Only                     8327
# All Inclusive                  707
# Breakfast, Lunch & Dinner      446
# Name: Meal, dtype: int64

# %%
plt.figure(figsize=(14,7))
sns.barplot(x,y,palette="dark:#5A9_r")
plt.xlabel('Meal Preference')
plt.ylabel('Customer Count')
plt.title('Meal Preference of Customers with  no Chilren or Kids')
plt.show()
# Out:
# C:\Users\Dhruv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
j=df['Booking Payment'].value_counts()
w=j.keys()
v=j.values

# %%
plt.pie(v,labels=w,colors=['#0A92A7','#0AA74B','red'])
plt.title('Booking Payment Preference')
plt.show()

# %%
q=df['Country'].value_counts().head(10)
a=q.keys()
b=q.values

# %%
sns.barplot(a,b,palette='flare')
plt.title('Top 10 Countries by Customers')#,fontdict={'color':'#D43165'}
plt.show()
# Out:
# C:\Users\Dhruv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
u=df['Booking Type'].value_counts()
w=u.keys()
v=u.values
plt.figure(figsize=(14,7))
plt.pie(v,labels=w,counterclock=False,startangle=15)
plt.title('Booking Type')
plt.show()

# %%
plt.figure(figsize=(14,7))
sns.countplot(x=df['Booking Type'],order=df['Booking Type'].value_counts(ascending=True).index,palette='flare')
plt.title('Customer Count by Booking Type')#,fontdict={'color':'#D43165'}
plt.show()

# %%
Total_repeated_guest=df['Repeated Guest'].sum()
Total_repeated_guest
# Out:
# 2802

# %%
#the below condition show 0 as repeated guest even though when the history is more than or equal to 1 which is only possible if the booking platform had the option of 'booking for someone else'.????????????????
df[(df['History']>=1) & (df['Repeated Guest']==0)]
# Out:
#       Type of Hotel  Year    Month Reservation Date  Arrival week  \
# 66            Motel  2016      May       25-05-2016            22
# 124           Villa  2017    April       01-05-2017            17
# 212           Villa  2016    March       14-03-2016            11
# 227           Villa  2016      May       18-05-2016            21
# 370           Motel  2017  January       28-01-2017             4
# ...             ...   ...      ...              ...           ...
# 89380         Villa  2017    April       23-04-2017            16
# 89658         Motel  2017     June       29-06-2017            26
# 89675         Villa  2017      May       03-05-2017            18
# 89828         Villa  2016  October       15-10-2016            41
# 89851         Villa  2016  October       17-10-2016            43
#
#        Arrival Date  Weekend Stays  Weekday Stays                Meal  \
# 66               24              0              1     Bed & Breakfast
# ...

# %%
t=df['History'].value_counts()[1:]

x=t.keys()
y=t.values
y.sum()
# Out:
# 2877

# %%
plt.figure(figsize=(14,7))
sns.barplot(x,y,palette='flare')
plt.title('Spread of Customer Retenstion')
plt.show()
# Out:
# C:\Users\Dhruv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df[df['Prev Cancel']>1]
# Out:
#       Type of Hotel  Year      Month Reservation Date  Arrival week  \
# 722           Motel  2016      March       09-03-2016            10
# 1182          Villa  2015  September       28-04-2015            39
# 1386          Villa  2016     August       23-11-2015            35
# 1634          Motel  2016    January       11-01-2016             3
# 1924          Motel  2016        May       17-12-2015            20
# ...             ...   ...        ...              ...           ...
# 88184         Motel  2016  September       28-09-2016            40
# 88488         Motel  2017       June       23-06-2017            25
# 89565         Motel  2017        May       14-05-2017            19
# 89583         Motel  2017   February       03-02-2017             5
# 89823         Villa  2017    January       02-02-2017             5
#
#        Arrival Date  Weekend Stays  Weekday Stays                       Meal  \
# ...

# %%
z=df['Prev Cancel'].value_counts()[2:]
x=z.keys()
y=z.values
z
# Out:
# 2     106
# 3      36
# 4      18
# 11     14
# 6      14
# 5      11
# 24      7
# 25      3
# 13      3
# 26      3
# 19      2
# 14      1
# Name: Prev Cancel, dtype: int64

# %%
plt.figure(figsize=(14,7))
sns.barplot(x,y,palette='flare')
plt.xlabel('No. of Previous Cancellations')
plt.ylabel('Count of Customers')
plt.title('Customers count with more than 2 Previous Cancellations')
plt.show()
# Out:
# C:\Users\Dhruv\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
temp_df=df[df['Reserved Room']!=df['Assigned Room']]

# %%
plt.figure(figsize=(14,7))
sns.countplot(x=temp_df['Cancellation'],palette="dark:#5A9_r")
plt.xlabel('Cancellations')
plt.ylabel('Count of Customers')
plt.title('Cancellations due to Unassignment of Prefered Rooms')
plt.show()

# %%
room_revenue=nc_df.groupby('Assigned Room')['Revenue'].sum().sort_values(ascending=False)
room_revenue
# Out:
# Assigned Room
# A    9265064.98
# D    5370962.00
# E    1998384.00
# F    1040856.00
# G     789357.00
# C     563282.00
# B     287168.20
# H     189566.00
# I      28128.00
# K      24972.00
# Name: Revenue, dtype: float64

# %%
plt.figure(figsize=(14,7))
sns.barplot(x=room_revenue.index,y=room_revenue.values,palette="dark:#5A9_r")
plt.xlabel('Room Type')
plt.ylabel('Revenue in US ($)')
plt.title('Revenue by Room Type')
plt.show()

# %%
Avg_room_price=nc_df.groupby('Assigned Room')['Per Day Charges'].mean().sort_values(ascending=False)
Avg_room_price
# Out:
# Assigned Room
# H    162.024055
# G    161.818037
# F    143.394701
# E    112.793463
# C    105.144993
# D    102.975277
# B     95.589964
# A     92.525683
# K     81.323741
# I     55.981595
# Name: Per Day Charges, dtype: float64

# %%
plt.figure(figsize=(14,7))
sns.barplot(x=Avg_room_price.index,y=Avg_room_price.values,palette="dark:#5A9_r")
plt.xlabel('Room Type')
plt.ylabel('Average Revenue in US ($)')
plt.title(' Average Revenue by Room Type')
plt.show()

# %%
Avg_booking_changes=df.groupby('Customer')['Booking Changes'].mean().sort_values()
Avg_booking_changes
# Out:
# Customer
# Contract           0.142432
# Transient          0.207400
# Group              0.276888
# Transient-Party    0.313998
# Name: Booking Changes, dtype: float64

# %%
plt.figure(figsize=(14,7))
sns.barplot(x=Avg_booking_changes.index,y=Avg_booking_changes.values,palette="dark:#5A9_r")
plt.xlabel('Customer Type')
plt.ylabel('Avg. Booking Changes')
plt.title('Avg. booking changes by Customer Type')
plt.show()

# %%
avg_wait_time=df.groupby('Booking Type')['Waiting List'].mean().sort_values()
avg_wait_time
# Out:
# Booking Type
# Aviation         0.000000
# Complementary    0.000000
# Online TA        0.001870
# Website          0.023635
# Corporate        0.126154
# Groups           3.685052
# Offline TA/TO    3.724547
# Name: Waiting List, dtype: float64

# %%
plt.figure(figsize=(14,7))
sns.barplot(x=avg_wait_time.index,y=avg_wait_time.values,palette="dark:#5A9_r")
plt.xlabel('Booking Type')
plt.ylabel('Avg. Waiting Period')
plt.title('Waiting Period for booking confirmtion by Booking Type')
plt.show()

# %%
avg_wait_time=df.groupby('Customer')['Waiting List'].mean().sort_values()
avg_wait_time
# Out:
# Customer
# Contract           0.000000
# Group              0.398169
# Transient          0.907878
# Transient-Party    3.046569
# Name: Waiting List, dtype: float64

# %%
plt.figure(figsize=(14,7))
sns.barplot(x=avg_wait_time.index,y=avg_wait_time.values,palette="dark:#5A9_r")
plt.xlabel('Customer Type')
plt.ylabel('Avg. Waiting Period')
plt.title('Waiting Period for booking confirmtion by Customer Type')
plt.show()

# %%
avg_revenue=nc_df.groupby('Customer')['Revenue'].mean().sort_values()
avg_revenue
# Out:
# Customer
# Group              268.165000
# Transient-Party    277.021370
# Transient          364.148517
# Contract           465.969888
# Name: Revenue, dtype: float64

# %%
plt.figure(figsize=(14,7))
sns.barplot(x=avg_revenue.index,y=avg_revenue.values,palette="dark:#5A9_r")
plt.xlabel('Customer Type')
plt.ylabel('Avg Revenue')
plt.title('Average Revenue by Customer Type')
plt.show()

# %%
t=df.groupby('Reservation Status')['Year'].count()

# %%
temp_df=pd.DataFrame(t)
temp_df
# Out:
#                      Year
# Reservation Status
# Canceled            32718
# Check-Out           56292
# No-Show               908

# %%
avg_reserve_status=(temp_df['Year']/len(df))*100
avg_reserve_status=avg_reserve_status.sort_values(ascending=False)
avg_reserve_status
# Out:
# Reservation Status
# Check-Out    62.603706
# Canceled     36.386485
# No-Show       1.009809
# Name: Year, dtype: float64

# %%
cancel=df.groupby('Customer')['Cancellation'].sum().sort_values()
cancel
# Out:
# Customer
# Group                 37
# Contract            1138
# Transient-Party     5351
# Transient          27088
# Name: Cancellation, dtype: int64

# %%
plt.figure(figsize=(14,7))
sns.barplot(x=cancel.index,y=cancel.values,palette="dark:#5A9_r")
plt.xlabel('Customer Type')
plt.ylabel('Count of Cancellations')
plt.title('Cancellations by Customer Type')
plt.show()

# %%
df['Stay_Duration']=df['Weekend Stays']+df['Weekday Stays']

# %%
b=df.groupby('Customer')['Stay_Duration'].mean().sort_values()

# %%
plt.figure(figsize=(14,7))
sns.barplot(x=b.index,y=b.values,palette="dark:#5A9_r")
plt.xlabel('Customer Type')
plt.ylabel('Average Stay Duration')
plt.title('Average Stay Duration by Customer Type')
plt.show()

# %%
Advance_book=df.groupby('Customer')['Booking Done'].mean().sort_values()
Advance_book
# Out:
# Customer
# Group               49.743707
# Transient           96.313498
# Contract           142.404698
# Transient-Party    142.820588
# Name: Booking Done, dtype: float64

# %%
plt.figure(figsize=(14,7))
sns.barplot(x=Advance_book.index,y=Advance_book.values,palette="dark:#5A9_r")
plt.xlabel('Customer Type')
plt.ylabel('Average Advance days of booking')
plt.title('Advance Booking by Customer Type')
plt.show()

# %%
sns.boxplot(x='Cancellation',y='Booking Done',data=df)
# Out:
# <AxesSubplot:xlabel='Cancellation', ylabel='Booking Done'>

# %%
sns.distplot(df['Booking Done'])
plt.title('Density Plot for Advance Booking')
plt.show()
# Out:
# C:\Users\Dhruv\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
df.groupby('Parking at premises')['Cancellation'].sum()
# Out:
# Parking at premises
# 0    33614
# 1        0
# 2        0
# Name: Cancellation, dtype: int64

# %%
#x=df['Cancellation'],y=df['Parking at premises']
plt.figure(figsize=(14,7))
sns.barplot(x=df['Cancellation'],y=df['Parking at premises'],palette="dark:#5A9_r")
plt.xlabel('Cancellations')
plt.ylabel('Parking at Premises')
plt.title('Cancellations due to unavailability of Parking at Premises')
plt.show()

# %%
#Average days of booking done in advance
Advance_booking=df['Booking Done'].mean()
Advance_booking
# Out:
# 107.30711314753442

# %%
df
# Out:
#       Type of Hotel  Year     Month Reservation Date  Arrival week  \
# 0             Motel  2015      July       03-08-2015            31
# 1             Villa  2016    August       30-08-2016            35
# 2             Villa  2017     April       23-04-2017            16
# 3             Motel  2016      June       29-06-2016            27
# 4             Motel  2016    August       22-08-2016            34
# ...             ...   ...       ...              ...           ...
# 89995         Motel  2017     April       07-01-2017            15
# 89996         Villa  2016     April       01-03-2016            17
# 89997         Motel  2017      July       10-07-2017            27
# 89998         Motel  2016  December       26-12-2016            52
# 89999         Motel  2017   January       21-10-2016             4
#
#        Arrival Date  Weekend Stays  Weekday Stays                Meal  \
# 0                28              2              3     Bed & Breakfast
# ...
